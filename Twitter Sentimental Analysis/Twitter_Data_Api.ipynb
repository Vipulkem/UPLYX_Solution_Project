# %% [markdown]
# ## Sentimant Analysis with Tweeter/tweepy
#
# - Setup Environment

# %%
# !pip install tweepy
# !pip install nltk
# !pip install wordcloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tweepy in C:\Users\vipul\AppData\Roaming\Python\Python314\site-packages (4.16.0)
# Requirement already satisfied: oauthlib<4,>=3.2.0 in C:\Users\vipul\AppData\Roaming\Python\Python314\site-packages (from tweepy) (3.3.1)
# Requirement already satisfied: requests<3,>=2.27.0 in C:\Users\vipul\AppData\Roaming\Python\Python314\site-packages (from tweepy) (2.33.1)
# Requirement already satisfied: requests-oauthlib<3,>=1.2.0 in C:\Users\vipul\AppData\Roaming\Python\Python314\site-packages (from tweepy) (2.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\vipul\AppData\Roaming\Python\Python314\site-packages (from requests<3,>=2.27.0->tweepy) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\vipul\AppData\Roaming\Python\Python314\site-packages (from requests<3,>=2.27.0->tweepy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\vipul\AppData\Roaming\Python\Python314\site-packages (from requests<3,>=2.27.0->tweepy) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\vipul\AppData\Roaming\Python\Python314\site-packages (from requests<3,>=2.27.0->tweepy) (2026.2.25)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in C:\Users\vipul\AppData\Roaming\Python\Python314\site-packages (3.9.4)
# Requirement already satisfied: click in C:\Users\vipul\AppData\Roaming\Python\Python314\site-packages (from nltk) (8.3.2)
# Requirement already satisfied: joblib in C:\Users\vipul\AppData\Roaming\Python\Python314\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in C:\Users\vipul\AppData\Roaming\Python\Python314\site-packages (from nltk) (2026.4.4)
# Requirement already satisfied: tqdm in C:\Users\vipul\AppData\Roaming\Python\Python314\site-packages (from nltk) (4.67.3)
# Requirement already satisfied: colorama in C:\Users\vipul\AppData\Roaming\Python\Python314\site-packages (from click->nltk) (0.4.6)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting wordcloud
#   Downloading wordcloud-1.9.6-cp314-cp314-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.19.3 in C:\Users\vipul\AppData\Roaming\Python\Python314\site-packages (from wordcloud) (2.4.4)
# Requirement already satisfied: pillow in C:\Users\vipul\AppData\Roaming\Python\Python314\site-packages (from wordcloud) (12.2.0)
# Requirement already satisfied: matplotlib in C:\Users\vipul\AppData\Roaming\Python\Python314\site-packages (from wordcloud) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\vipul\AppData\Roaming\Python\Python314\site-packages (from matplotlib->wordcloud) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\vipul\AppData\Roaming\Python\Python314\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\vipul\AppData\Roaming\Python\Python314\site-packages (from matplotlib->wordcloud) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\vipul\AppData\Roaming\Python\Python314\site-packages (from matplotlib->wordcloud) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\vipul\AppData\Roaming\Python\Python314\site-packages (from matplotlib->wordcloud) (25.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\vipul\AppData\Roaming\Python\Python314\site-packages (from matplotlib->wordcloud) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\vipul\AppData\Roaming\Python\Python314\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\vipul\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Downloading wordcloud-1.9.6-cp314-cp314-win_amd64.whl (308 kB)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.6
#   WARNING: The script wordcloud_cli.exe is installed in 'C:\Users\vipul\AppData\Roaming\Python\Python314\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import tweepy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk
nltk.download('vader_lexicon')

from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import warnings
warnings.filterwarnings('ignore')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\vipul\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.6-cp313-cp313-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.19.3 in c:\Users\vipul\AppData\Local\Programs\Python\Python313\Lib\site-packages (from wordcloud) (2.1.3)
# Requirement already satisfied: pillow in c:\Users\vipul\AppData\Local\Programs\Python\Python313\Lib\site-packages (from wordcloud) (11.0.0)
# Requirement already satisfied: matplotlib in c:\Users\vipul\AppData\Local\Programs\Python\Python313\Lib\site-packages (from wordcloud) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\vipul\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib->wordcloud) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\Users\vipul\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\vipul\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib->wordcloud) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\vipul\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib->wordcloud) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\Users\vipul\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib->wordcloud) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\Users\vipul\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib->wordcloud) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\Users\vipul\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\Users\vipul\AppData\Local\Programs\Python\Python313\Lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.6-cp313-cp313-win_amd64.whl (306 kB)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.6
# Note: you may need to restart the kernel to use updated packages.
